# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import torch
from torch.nn import Module, Conv1d, MaxPool1d, Linear, Dropout, Sigmoid, BCEWithLogitsLoss
from torch.optim import Adam
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score, auc, precision_recall_curve, classification_report

# %%
# Constants
DATASET_PATH = "../../data/stroke_dataset.csv"
TARGET_NAME = DATASET_PATH.split("/")[-1].split("_")[0]
TARGET_CLASS = "class_" + TARGET_NAME + "_w8"

LEARNING_RATE = 0.001 # The learning rate for the optimizer 
MAX_EPOCHS = 100 # The maximum number of epochs to train the model
BATCH_SIZE = 32 # Number of samples per batch
DROPOUT = 0.5 # The dropout rate
CNN_CHANNELS = 64 # Number of output channels of the convolutional layer
KERNEL_SIZE = 3 # The size of the kernel in the convolutional layer
POOL_SIZE = 2 # The size of the pooling layer
DENSE_UNITS = 1 # Number of units in the dense layer
ACTIVATION = 'sigmoid'
LOSS = BCEWithLogitsLoss()
METRICS = ['accuracy']
VALIDATION_SPLIT = 0.1 # The percentage of the training set to use as validation
PATIENCE = 10 # The number of epochs to wait before early stopping if no improvement is made
NUM_LAYERS = 2 # The number of layers in the model
TEST_SIZE = 0.1 # The percentage of the dataset to use as test set

print(f"Dataset: {DATASET_PATH}")
print(f"Target: {TARGET_NAME}")
print(f"Target class: {TARGET_CLASS}")
# Out:
# Dataset: ../../data/stroke_dataset.csv
# Target: stroke
# Target class: class_stroke_w8

# %%
data = pd.read_csv(DATASET_PATH)
data.replace('?', np.nan, inplace=True)
data = data.apply(pd.to_numeric, errors='coerce')
data.fillna(0, inplace=True)

# %%
# Extract features and target variables
target_wave_suffix = TARGET_CLASS.split('_')[-1]
target_wave_number = int(target_wave_suffix[1:])
class_vars_to_remove = [col for col in data.columns if col.startswith("class_") and TARGET_CLASS not in col]
features_to_remove = [col for col in data.columns if any(col.endswith(f'w{wave}') for wave in range(target_wave_number + 1, 9))]

columns_to_remove = class_vars_to_remove + features_to_remove
data_copy = data.drop(columns=columns_to_remove)

X = data_copy.drop(columns=[TARGET_CLASS])
y = data_copy[TARGET_CLASS]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Identify features by wave
column_names = X.columns
wave_identifiers = sorted(set(col.split('_')[-1] for col in column_names if col != 'sex' and col != 'indager_wave8' and col != 'dheas_wave4' and col != 'apoe_wave2'))
non_longitudinal_features = [col for col in column_names if not col.endswith('w1') and not col.endswith('w2') and not col.endswith('w3') and not col.endswith('w4') and not col.endswith('w5') and not col.endswith('w6') and not col.endswith('w7') and not col.endswith('w8')]

print(f"Wave identifiers: {wave_identifiers}")
print(non_longitudinal_features)
# Out:
# Wave identifiers: ['w2', 'w4', 'w6', 'w8']
# ['indager_wave8', 'sex', 'apoe_wave2', 'dheas_wave4']

# %%
# Group features by waves
features_by_wave = {wave: [] for wave in wave_identifiers}
for col in column_names:
    if col not in non_longitudinal_features:
        wave = col.split('_')[-1]
        features_by_wave[wave].append(col)
        print(wave, col)
# Out:
# w2 bmiobe_w2
# w4 bmiobe_w4
# w6 bmiobe_w6
# w2 cfib_w2
# w4 cfib_w4
# w6 cfib_w6
# w8 cfib_w8
# w2 chestin_w2
# w4 chestin_w4
# w6 chestin_w6
# w2 chol_w2
# w4 chol_w4
# w6 chol_w6
# w8 chol_w8
# w2 clotb_w2
# w4 clotb_w4
# w6 clotb_w6
# w8 clotb_w8
# w2 diaval_w2
# w4 diaval_w4
# w6 diaval_w6
# w8 diaval_w8
# w2 eyesurg_w2
# w4 eyesurg_w4
# w6 eyesurg_w6
# w2 fglu_w2
# w4 fglu_w4
# w6 fglu_w6
# w8 fglu_w8
# w2 hastro_w2
# w4 hastro_w4
# w6 hastro_w6
# w2 hasurg_w2
# w4 hasurg_w4
# w6 hasurg_w6
# w2 hba1c_w2
# w4 hba1c_w4
# w6 hba1c_w6
# w8 hba1c_w8
# w2 hdl_w2
# w4 hdl_w4
# w6 hdl_w6
# w8 hdl_w8
# w2 hgb_w2
# w4 hgb_w4
# w6 hgb_w6
# w8 hgb_w8
# w2 hipval_w2
# w4 hipval_w4
# w2 hscrp_w2
# w4 hscrp_w4
# w6 hscrp_w6
# w8 hscrp_w8
# w2 htfev_w2
# w4 htfev_w4
# w6 htfev_w6
# w2 htfvc_w2
# w4 htfvc_w4
# w6 htfvc_w6
# w2 htpf_w2
# w4 htpf_w4
# w2 htval_w2
# w4 htval_w4
# w6 htval_w6
# w4 igf1_w4
# w6 igf1_w6
# w8 igf1_w8
# w2 ldl_w2
# w4 ldl_w4
# w6 ldl_w6
# w8 ldl_w8
# w2 mapval_w2
# w4 mapval_w4
# w6 mapval_w6
# w8 mapval_w8
# w4 mch_w4
# w6 mch_w6
# w8 mch_w8
# w2 mmcrre_w2
# w4 mmcrre_w4
# w6 mmcrre_w6
# w2 mmftre2_w2
# w4 mmftre2_w4
# w6 mmftre2_w6
# w2 mmgsdavg_w2
# w4 mmgsdavg_w4
# w6 mmgsdavg_w6
# w8 mmgsdavg_w8
# w2 mmgsnavg_w2
# w4 mmgsnavg_w4
# w6 mmgsnavg_w6
# w8 mmgsnavg_w8
# w2 mmlore_w2
# w4 mmlore_w4
# w6 mmlore_w6
# w2 mmlsre_w2
# w4 mmlsre_w4
# w6 mmlsre_w6
# w2 mmrroc_w2
# w4 mmrroc_w4
# w6 mmrroc_w6
# w2 mmssre_w2
# w4 mmssre_w4
# w6 mmssre_w6
# w2 mmstre_w2
# w4 mmstre_w4
# w6 mmstre_w6
# w2 pulval_w2
# w4 pulval_w4
# w6 pulval_w6
# w8 pulval_w8
# w2 rtin_w2
# w4 rtin_w4
# w6 rtin_w6
# w8 rtin_w8
# w2 sysval_w2
# w4 sysval_w4
# w6 sysval_w6
# w8 sysval_w8
# w2 trig_w2
# w4 trig_w4
# w6 trig_w6
# w8 trig_w8
# w6 vitd_w6
# w8 vitd_w8
# w4 wbc_w4
# w6 wbc_w6
# w8 wbc_w8
# w2 whval_w2
# w4 whval_w4
# w2 wstval_w2
# w4 wstval_w4
# w6 wstval_w6
# w2 wtval_w2
# w4 wtval_w4
# w6 wtval_w6

# %%
# Prepare data for RNN
n_samples = X_scaled.shape[0]
n_timesteps = len(wave_identifiers)
n_features_per_wave = {wave: len(features) for wave, features in features_by_wave.items()}
max_features = max(n_features_per_wave.values())

print(f"Number of samples: {n_samples}")
print(f"Number of waves: {n_timesteps}")
print(f"Wave identifiers: {wave_identifiers}")
print(f"Number of features per wave: {n_features_per_wave}")
# Out:
# Number of samples: 7097
# Number of waves: 4
# Wave identifiers: ['w2', 'w4', 'w6', 'w8']
# Number of features per wave: {'w2': 37, 'w4': 40, 'w6': 38, 'w8': 21}

# %%
# Reshape data without non-longitudinal features
X_reshaped = np.zeros((n_samples, n_timesteps, max_features))
for i, wave in enumerate(wave_identifiers):
    wave_features = features_by_wave[wave]
    indices = [column_names.get_loc(f) for f in wave_features]
    X_reshaped[:, i, :len(indices)] = X_scaled[:, indices]
    print(f"Wave {wave} features: {wave_features}")
print(f"X reshaped shape: {X_reshaped.shape}")
# Out:
# Wave w2 features: ['bmiobe_w2', 'cfib_w2', 'chestin_w2', 'chol_w2', 'clotb_w2', 'diaval_w2', 'eyesurg_w2', 'fglu_w2', 'hastro_w2', 'hasurg_w2', 'hba1c_w2', 'hdl_w2', 'hgb_w2', 'hipval_w2', 'hscrp_w2', 'htfev_w2', 'htfvc_w2', 'htpf_w2', 'htval_w2', 'ldl_w2', 'mapval_w2', 'mmcrre_w2', 'mmftre2_w2', 'mmgsdavg_w2', 'mmgsnavg_w2', 'mmlore_w2', 'mmlsre_w2', 'mmrroc_w2', 'mmssre_w2', 'mmstre_w2', 'pulval_w2', 'rtin_w2', 'sysval_w2', 'trig_w2', 'whval_w2', 'wstval_w2', 'wtval_w2']
# Wave w4 features: ['bmiobe_w4', 'cfib_w4', 'chestin_w4', 'chol_w4', 'clotb_w4', 'diaval_w4', 'eyesurg_w4', 'fglu_w4', 'hastro_w4', 'hasurg_w4', 'hba1c_w4', 'hdl_w4', 'hgb_w4', 'hipval_w4', 'hscrp_w4', 'htfev_w4', 'htfvc_w4', 'htpf_w4', 'htval_w4', 'igf1_w4', 'ldl_w4', 'mapval_w4', 'mch_w4', 'mmcrre_w4', 'mmftre2_w4', 'mmgsdavg_w4', 'mmgsnavg_w4', 'mmlore_w4', 'mmlsre_w4', 'mmrroc_w4', 'mmssre_w4', 'mmstre_w4', 'pulval_w4', 'rtin_w4', 'sysval_w4', 'trig_w4', 'wbc_w4', 'whval_w4', 'wstval_w4', 'wtval_w4']
# Wave w6 features: ['bmiobe_w6', 'cfib_w6', 'chestin_w6', 'chol_w6', 'clotb_w6', 'diaval_w6', 'eyesurg_w6', 'fglu_w6', 'hastro_w6', 'hasurg_w6', 'hba1c_w6', 'hdl_w6', 'hgb_w6', 'hscrp_w6', 'htfev_w6', 'htfvc_w6', 'htval_w6', 'igf1_w6', 'ldl_w6', 'mapval_w6', 'mch_w6', 'mmcrre_w6', 'mmftre2_w6', 'mmgsdavg_w6', 'mmgsnavg_w6', 'mmlore_w6', 'mmlsre_w6', 'mmrroc_w6', 'mmssre_w6', 'mmstre_w6', 'pulval_w6', 'rtin_w6', 'sysval_w6', 'trig_w6', 'vitd_w6', 'wbc_w6', 'wstval_w6', 'wtval_w6']
# Wave w8 features: ['cfib_w8', 'chol_w8', 'clotb_w8', 'diaval_w8', 'fglu_w8', 'hba1c_w8', 'hdl_w8', 'hgb_w8', 'hscrp_w8', 'igf1_w8', 'ldl_w8', 'mapval_w8', 'mch_w8', 'mmgsdavg_w8', 'mmgsnavg_w8', 'pulval_w8', 'rtin_w8', 'sysval_w8', 'trig_w8', 'vitd_w8', 'wbc_w8']
# X reshaped shape: (7097, 4, 40)

# %%
# Split data
X_train, X_test, y_train, y_test = train_test_split(X_reshaped, y, test_size=TEST_SIZE, random_state=42)

# PyTorch Dataset and DataLoader
train_dataset = TensorDataset(torch.tensor(X_train, dtype=torch.float32), torch.tensor(y_train.values, dtype=torch.float32))
test_dataset = TensorDataset(torch.tensor(X_test, dtype=torch.float32), torch.tensor(y_test.values, dtype=torch.float32))

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
print(f"X shape: {X_train.shape}")
print(f"y shape: {y_train.shape}")
print(f"Wave identifiers: {wave_identifiers}")
print(f"Number of features per wave: {n_features_per_wave}")
# Out:
# X shape: (6387, 4, 40)
# y shape: (6387,)
# Wave identifiers: ['w2', 'w4', 'w6', 'w8']
# Number of features per wave: {'w2': 37, 'w4': 40, 'w6': 38, 'w8': 21}

# %%
# Define the CNN model
class CNNModel(Module):
    def __init__(self, input_dim, num_channels, kernel_size, pool_size, dropout=0.0):
        super(CNNModel, self).__init__()
        self.conv1 = Conv1d(in_channels=input_dim, out_channels=num_channels, kernel_size=kernel_size, padding=1)
        self.pool = MaxPool1d(pool_size)
        self.dropout = Dropout(dropout)
        
        # Calculate the output size after Conv1d and MaxPool1d
        conv_output_size = ((n_timesteps - kernel_size + 2 * 1) // 1 + 1) // pool_size
        self.feature_dim = num_channels * conv_output_size

        self.fc = Linear(self.feature_dim, DENSE_UNITS)
        self.sigmoid = Sigmoid()

    def forward(self, x):
        x = x.permute(0, 2, 1)  # Change the dimension to (batch_size, input_dim, n_timesteps) for Conv1d
        x = self.pool(torch.relu(self.conv1(x)))
        x = x.view(x.size(0), -1)  # Flatten for the fully connected layer
        if self.dropout is not None:
            x = self.dropout(x)
        out = self.fc(x)
        out = self.sigmoid(out)
        return out

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
input_dim = X_train.shape[2]
model = CNNModel(input_dim=input_dim, num_channels=CNN_CHANNELS, kernel_size=KERNEL_SIZE, pool_size=POOL_SIZE, dropout=DROPOUT).to(device)
criterion = LOSS
optimizer = Adam(model.parameters(), lr=LEARNING_RATE)

# %%
# Training function
def train_model(model, train_loader, criterion, optimizer, n_epochs, device):
    model.train()
    for epoch in range(n_epochs):
        running_loss = 0.0
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            y_pred = model(X_batch)
            loss = criterion(y_pred.squeeze(), y_batch)
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * X_batch.size(0)
        epoch_loss = running_loss / len(train_loader.dataset)
        print(f"Epoch {epoch+1}/{n_epochs}, Loss: {epoch_loss:.4f}")

# %%
# Evaluation function
def evaluate_model(model, test_loader, device):
    model.eval()
    y_true = []
    y_pred = []
    
    with torch.no_grad(): 
        for X_batch, y_batch in test_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            y_true.extend(y_batch.cpu().numpy())
            y_pred_batch = model(X_batch)
            y_pred.extend(y_pred_batch.cpu().numpy())

    y_pred = np.array(y_pred).squeeze()
    
    # Convert predictions to binary values
    y_pred_binary = (y_pred > 0.5).astype(int)
    
    # Calculate metrics using binary predictions
    precision = precision_score(y_true, y_pred_binary)
    recall = recall_score(y_true, y_pred_binary)
    f1 = f1_score(y_true, y_pred_binary)
    
    # ROC-AUC and Precision-Recall AUC use the continuous y_pred
    roc_auc = roc_auc_score(y_true, y_pred)
    precision_curve, recall_curve, _ = precision_recall_curve(y_true, y_pred)
    auprc = auc(recall_curve, precision_curve)
    
    report = classification_report(y_true, y_pred_binary)
    conf_matrix = confusion_matrix(y_true, y_pred_binary)

    print(f'Test Precision: {precision:.4f}')
    print(f'Test Recall: {recall:.4f}')
    print(f'Test F1 Score: {f1:.4f}')
    print(f'Test ROC-AUC Score: {roc_auc:.4f}')
    print(f'Test AUPRC Score: {auprc:.4f}')
    print(f'Confusion Matrix:\n{conf_matrix}')
    print(f'Classification Report:\n{report}')
    return y_true, y_pred

# %%
from itertools import product

# Define hyperparameter grid
learning_rates = [0.001, 0.01]  # Include a broader range of learning rates
dropout_rates = [0.2, 0.5]  # Include an additional dropout rate for more variety
num_channels_options = [64, 128]  # Different numbers of output channels for the Conv1d layer
kernel_size_options = [3, 5]  # Different kernel sizes for the Conv1d layer

# All combinations of hyperparameters
hyperparameter_grid = list(product(learning_rates, dropout_rates, num_channels_options, kernel_size_options))

# %%
from sklearn.model_selection import KFold

def train_validate_model(model, train_loader, val_loader, criterion, optimizer, n_epochs, device):
    """Train the model and evaluate on validation set."""
    model.train()
    for epoch in range(n_epochs):
        running_loss = 0.0
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            optimizer.zero_grad()
            y_pred = model(X_batch)
            loss = criterion(y_pred.squeeze(), y_batch)
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * X_batch.size(0)
    
    # Evaluate on validation set
    model.eval()
    y_true, y_pred = [], []
    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            y_true.extend(y_batch.cpu().numpy())
            y_pred_batch = model(X_batch)
            y_pred.extend(y_pred_batch.cpu().numpy())
    
    y_pred = np.array(y_pred).squeeze()
    y_pred_binary = (y_pred > 0.5).astype(int)
    auc_score = roc_auc_score(y_true, y_pred)
    
    conf_matrix = confusion_matrix(y_true, y_pred_binary)
    
    return auc_score, conf_matrix

def grid_search(train_data, val_data, hyperparameter_grid, device, n_epochs=10):
    best_hyperparameters = None
    best_auc = float('-inf')
    best_conf_matrix = None

    for lr, dropout, num_channels, kernel_size in hyperparameter_grid:
        print(f"Training with learning rate: {lr}, dropout: {dropout}, channels: {num_channels}, kernel size: {kernel_size}")
        model = CNNModel(input_dim, num_channels, kernel_size, POOL_SIZE, dropout).to(device)
        optimizer = Adam(model.parameters(), lr=lr)
        criterion = BCEWithLogitsLoss()
        
        # Prepare data loaders
        train_loader = DataLoader(train_data, batch_size=BATCH_SIZE, shuffle=True)
        val_loader = DataLoader(val_data, batch_size=BATCH_SIZE, shuffle=False)
        
        # Train and evaluate
        auc, conf_matrix = train_validate_model(model, train_loader, val_loader, criterion, optimizer, n_epochs, device)
        
        # Save the best hyperparameters based on F1 score
        if auc > best_auc:
            best_auc = auc
            best_conf_matrix = conf_matrix
            best_hyperparameters = (lr, dropout, num_channels, kernel_size)
            print(f"Found new best hyperparameters: {best_hyperparameters}")

    return best_hyperparameters, best_auc, best_conf_matrix


# K-Fold Cross Validation
kf = KFold(n_splits=10, shuffle=True, random_state=42)
all_fold_results = []

best_results_per_fold = []

for fold, (train_index, test_index) in enumerate(kf.split(X_reshaped)):
    print(f'Fold {fold + 1}')
    
    # Split data into train and test sets for this fold
    X_train_fold, X_test_fold = X_reshaped[train_index], X_reshaped[test_index]
    y_train_fold, y_test_fold = y[train_index], y[test_index]
    
    # Further split train into learning and validation sets
    X_train_sub, X_val_sub, y_train_sub, y_val_sub = train_test_split(X_train_fold, y_train_fold, test_size=VALIDATION_SPLIT, random_state=42)
    
    # Convert to TensorDatasets
    train_data_sub = TensorDataset(torch.tensor(X_train_sub, dtype=torch.float32), torch.tensor(y_train_sub.values, dtype=torch.float32))
    val_data_sub = TensorDataset(torch.tensor(X_val_sub, dtype=torch.float32), torch.tensor(y_val_sub.values, dtype=torch.float32))
    
    # Perform grid search on the learning and validation set
    best_hyperparameters, best_auc, best_conf_matrix = grid_search(train_data_sub, val_data_sub, hyperparameter_grid, device, n_epochs=MAX_EPOCHS)
    
    print(f"Best Hyperparameters for Fold {fold + 1}: {best_hyperparameters}")
    
    best_results_per_fold.append([best_hyperparameters, best_auc, best_conf_matrix])
    
    # Unpacking the correct hyperparameters for CNNModel
    lr, dropout, num_channels, kernel_size = best_hyperparameters
    print(f"Training on full training set with best hyperparameters: {best_hyperparameters}")
    model = CNNModel(input_dim, num_channels, kernel_size, POOL_SIZE, dropout).to(device)
    optimizer = Adam(model.parameters(), lr=lr)
    
    # Prepare final train and test loaders
    train_data_final = TensorDataset(torch.tensor(X_train_fold, dtype=torch.float32), torch.tensor(y_train_fold.values, dtype=torch.float32))
    test_data_final = TensorDataset(torch.tensor(X_test_fold, dtype=torch.float32), torch.tensor(y_test_fold.values, dtype=torch.float32))
    
    train_loader_final = DataLoader(train_data_final, batch_size=BATCH_SIZE, shuffle=True)
    test_loader_final = DataLoader(test_data_final, batch_size=BATCH_SIZE, shuffle=False)
    
    # Train on the full training set
    train_model(model, train_loader_final, criterion, optimizer, MAX_EPOCHS, device)
    
    # Evaluate on the test set
    results = evaluate_model(model, test_loader_final, device)
# Out:
# Fold 1
# Training with learning rate: 0.001, dropout: 0.2, channels: 64, kernel size: 3
# Found new best hyperparameters: (0.001, 0.2, 64, 3)
# Training with learning rate: 0.001, dropout: 0.2, channels: 64, kernel size: 5
# Training with learning rate: 0.001, dropout: 0.2, channels: 128, kernel size: 3
# Training with learning rate: 0.001, dropout: 0.2, channels: 128, kernel size: 5
# Training with learning rate: 0.001, dropout: 0.5, channels: 64, kernel size: 3
# Training with learning rate: 0.001, dropout: 0.5, channels: 64, kernel size: 5
# Training with learning rate: 0.001, dropout: 0.5, channels: 128, kernel size: 3
# Found new best hyperparameters: (0.001, 0.5, 128, 3)
# Training with learning rate: 0.001, dropout: 0.5, channels: 128, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.2, channels: 64, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.2, channels: 64, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.2, channels: 128, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.2, channels: 128, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.5, channels: 64, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.5, channels: 64, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.5, channels: 128, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.5, channels: 128, kernel size: 5
# Best Hyperparameters for Fold 1: (0.001, 0.5, 128, 3)
# Training on full training set with best hyperparameters: (0.001, 0.5, 128, 3)
# Epoch 1/100, Loss: 0.7097
# Epoch 2/100, Loss: 0.6936
# Epoch 3/100, Loss: 0.6933
# Epoch 4/100, Loss: 0.6932
# Epoch 5/100, Loss: 0.6932
# Epoch 6/100, Loss: 0.6932
# Epoch 7/100, Loss: 0.6932
# Epoch 8/100, Loss: 0.6932
# Epoch 9/100, Loss: 0.6932
# Epoch 10/100, Loss: 0.6932
# Epoch 11/100, Loss: 0.6932
# Epoch 12/100, Loss: 0.6932
# Epoch 13/100, Loss: 0.6932
# Epoch 14/100, Loss: 0.6932
# Epoch 15/100, Loss: 0.6932
# Epoch 16/100, Loss: 0.6932
# Epoch 17/100, Loss: 0.6932
# Epoch 18/100, Loss: 0.6932
# Epoch 19/100, Loss: 0.6932
# Epoch 20/100, Loss: 0.6931
# Epoch 21/100, Loss: 0.6931
# Epoch 22/100, Loss: 0.6931
# Epoch 23/100, Loss: 0.6931
# Epoch 24/100, Loss: 0.6931
# Epoch 25/100, Loss: 0.6931
# Epoch 26/100, Loss: 0.6931
# Epoch 27/100, Loss: 0.6931
# Epoch 28/100, Loss: 0.6931
# Epoch 29/100, Loss: 0.6931
# Epoch 30/100, Loss: 0.6931
# Epoch 31/100, Loss: 0.6931
# Epoch 32/100, Loss: 0.6931
# Epoch 33/100, Loss: 0.6931
# Epoch 34/100, Loss: 0.6931
# Epoch 35/100, Loss: 0.6931
# Epoch 36/100, Loss: 0.6931
# Epoch 37/100, Loss: 0.6931
# Epoch 38/100, Loss: 0.6931
# Epoch 39/100, Loss: 0.6931
# Epoch 40/100, Loss: 0.6931
# Epoch 41/100, Loss: 0.6931
# Epoch 42/100, Loss: 0.6931
# Epoch 43/100, Loss: 0.6931
# Epoch 44/100, Loss: 0.6931
# Epoch 45/100, Loss: 0.6931
# Epoch 46/100, Loss: 0.6931
# Epoch 47/100, Loss: 0.6931
# Epoch 48/100, Loss: 0.6931
# Epoch 49/100, Loss: 0.6931
# Epoch 50/100, Loss: 0.6931
# Epoch 51/100, Loss: 0.6931
# Epoch 52/100, Loss: 0.6931
# Epoch 53/100, Loss: 0.6931
# Epoch 54/100, Loss: 0.6931
# Epoch 55/100, Loss: 0.6931
# Epoch 56/100, Loss: 0.6931
# Epoch 57/100, Loss: 0.6931
# Epoch 58/100, Loss: 0.6931
# Epoch 59/100, Loss: 0.6930
# Epoch 60/100, Loss: 0.6930
# Epoch 61/100, Loss: 0.6930
# Epoch 62/100, Loss: 0.6930
# Epoch 63/100, Loss: 0.6930
# Epoch 64/100, Loss: 0.6930
# Epoch 65/100, Loss: 0.6930
# Epoch 66/100, Loss: 0.6930
# Epoch 67/100, Loss: 0.6930
# Epoch 68/100, Loss: 0.6930
# Epoch 69/100, Loss: 0.6930
# Epoch 70/100, Loss: 0.6930
# Epoch 71/100, Loss: 0.6930
# Epoch 72/100, Loss: 0.6930
# Epoch 73/100, Loss: 0.6930
# Epoch 74/100, Loss: 0.6930
# Epoch 75/100, Loss: 0.6930
# Epoch 76/100, Loss: 0.6930
# Epoch 77/100, Loss: 0.6929
# Epoch 78/100, Loss: 0.6930
# Epoch 79/100, Loss: 0.6929
# Epoch 80/100, Loss: 0.6929
# Epoch 81/100, Loss: 0.6930
# Epoch 82/100, Loss: 0.6929
# Epoch 83/100, Loss: 0.6929
# Epoch 84/100, Loss: 0.6929
# Epoch 85/100, Loss: 0.6929
# Epoch 86/100, Loss: 0.6929
# Epoch 87/100, Loss: 0.6929
# Epoch 88/100, Loss: 0.6929
# Epoch 89/100, Loss: 0.6929
# Epoch 90/100, Loss: 0.6929
# Epoch 91/100, Loss: 0.6929
# Epoch 92/100, Loss: 0.6929
# Epoch 93/100, Loss: 0.6929
# Epoch 94/100, Loss: 0.6929
# Epoch 95/100, Loss: 0.6929
# Epoch 96/100, Loss: 0.6929
# Epoch 97/100, Loss: 0.6929
# Epoch 98/100, Loss: 0.6929
# Epoch 99/100, Loss: 0.6929
# Epoch 100/100, Loss: 0.6929
# Test Precision: 0.0000
# Test Recall: 0.0000
# Test F1 Score: 0.0000
# Test ROC-AUC Score: 0.5384
# Test AUPRC Score: 0.0636
# Confusion Matrix:
# [[668   0]
#  [ 42   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.94      1.00      0.97       668
#          1.0       0.00      0.00      0.00        42
#
#     accuracy                           0.94       710
#    macro avg       0.47      0.50      0.48       710
# weighted avg       0.89      0.94      0.91       710
#
# Fold 2
# Training with learning rate: 0.001, dropout: 0.2, channels: 64, kernel size: 3
# c:\Users\Grego\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Grego\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Grego\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Grego\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Found new best hyperparameters: (0.001, 0.2, 64, 3)
# Training with learning rate: 0.001, dropout: 0.2, channels: 64, kernel size: 5
# Found new best hyperparameters: (0.001, 0.2, 64, 5)
# Training with learning rate: 0.001, dropout: 0.2, channels: 128, kernel size: 3
# Training with learning rate: 0.001, dropout: 0.2, channels: 128, kernel size: 5
# Found new best hyperparameters: (0.001, 0.2, 128, 5)
# Training with learning rate: 0.001, dropout: 0.5, channels: 64, kernel size: 3
# Training with learning rate: 0.001, dropout: 0.5, channels: 64, kernel size: 5
# Found new best hyperparameters: (0.001, 0.5, 64, 5)
# Training with learning rate: 0.001, dropout: 0.5, channels: 128, kernel size: 3
# Training with learning rate: 0.001, dropout: 0.5, channels: 128, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.2, channels: 64, kernel size: 3
# Found new best hyperparameters: (0.01, 0.2, 64, 3)
# Training with learning rate: 0.01, dropout: 0.2, channels: 64, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.2, channels: 128, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.2, channels: 128, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.5, channels: 64, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.5, channels: 64, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.5, channels: 128, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.5, channels: 128, kernel size: 5
# Best Hyperparameters for Fold 2: (0.01, 0.2, 64, 3)
# Training on full training set with best hyperparameters: (0.01, 0.2, 64, 3)
# Epoch 1/100, Loss: 0.6964
# Epoch 2/100, Loss: 0.6931
# Epoch 3/100, Loss: 0.6931
# Epoch 4/100, Loss: 0.6931
# Epoch 5/100, Loss: 0.6931
# Epoch 6/100, Loss: 0.6931
# Epoch 7/100, Loss: 0.6931
# Epoch 8/100, Loss: 0.6931
# Epoch 9/100, Loss: 0.6931
# Epoch 10/100, Loss: 0.6931
# Epoch 11/100, Loss: 0.6931
# Epoch 12/100, Loss: 0.6931
# Epoch 13/100, Loss: 0.6931
# Epoch 14/100, Loss: 0.6931
# Epoch 15/100, Loss: 0.6931
# Epoch 16/100, Loss: 0.6931
# Epoch 17/100, Loss: 0.6931
# Epoch 18/100, Loss: 0.6931
# Epoch 19/100, Loss: 0.6931
# Epoch 20/100, Loss: 0.6931
# Epoch 21/100, Loss: 0.6931
# Epoch 22/100, Loss: 0.6931
# Epoch 23/100, Loss: 0.6931
# Epoch 24/100, Loss: 0.6931
# Epoch 25/100, Loss: 0.6931
# Epoch 26/100, Loss: 0.6931
# Epoch 27/100, Loss: 0.6931
# Epoch 28/100, Loss: 0.6931
# Epoch 29/100, Loss: 0.6931
# Epoch 30/100, Loss: 0.6931
# Epoch 31/100, Loss: 0.6931
# Epoch 32/100, Loss: 0.6931
# Epoch 33/100, Loss: 0.6931
# Epoch 34/100, Loss: 0.6931
# Epoch 35/100, Loss: 0.6931
# Epoch 36/100, Loss: 0.6931
# Epoch 37/100, Loss: 0.6931
# Epoch 38/100, Loss: 0.6931
# Epoch 39/100, Loss: 0.6931
# Epoch 40/100, Loss: 0.6931
# Epoch 41/100, Loss: 0.6931
# Epoch 42/100, Loss: 0.6931
# Epoch 43/100, Loss: 0.6931
# Epoch 44/100, Loss: 0.6931
# Epoch 45/100, Loss: 0.6931
# Epoch 46/100, Loss: 0.6931
# Epoch 47/100, Loss: 0.6931
# Epoch 48/100, Loss: 0.6931
# Epoch 49/100, Loss: 0.6931
# Epoch 50/100, Loss: 0.6931
# Epoch 51/100, Loss: 0.6931
# Epoch 52/100, Loss: 0.6931
# Epoch 53/100, Loss: 0.6931
# Epoch 54/100, Loss: 0.6931
# Epoch 55/100, Loss: 0.6931
# Epoch 56/100, Loss: 0.6931
# Epoch 57/100, Loss: 0.6931
# Epoch 58/100, Loss: 0.6931
# Epoch 59/100, Loss: 0.6931
# Epoch 60/100, Loss: 0.6931
# Epoch 61/100, Loss: 0.6931
# Epoch 62/100, Loss: 0.6931
# Epoch 63/100, Loss: 0.6931
# Epoch 64/100, Loss: 0.6931
# Epoch 65/100, Loss: 0.6931
# Epoch 66/100, Loss: 0.6931
# Epoch 67/100, Loss: 0.6931
# Epoch 68/100, Loss: 0.6931
# Epoch 69/100, Loss: 0.6931
# Epoch 70/100, Loss: 0.6931
# Epoch 71/100, Loss: 0.6931
# Epoch 72/100, Loss: 0.6931
# Epoch 73/100, Loss: 0.6931
# Epoch 74/100, Loss: 0.6931
# Epoch 75/100, Loss: 0.6931
# Epoch 76/100, Loss: 0.6931
# Epoch 77/100, Loss: 0.6931
# Epoch 78/100, Loss: 0.6931
# Epoch 79/100, Loss: 0.6931
# Epoch 80/100, Loss: 0.6931
# Epoch 81/100, Loss: 0.6931
# Epoch 82/100, Loss: 0.6931
# Epoch 83/100, Loss: 0.6931
# Epoch 84/100, Loss: 0.6931
# Epoch 85/100, Loss: 0.6931
# Epoch 86/100, Loss: 0.6931
# Epoch 87/100, Loss: 0.6931
# Epoch 88/100, Loss: 0.6931
# Epoch 89/100, Loss: 0.6931
# Epoch 90/100, Loss: 0.6931
# Epoch 91/100, Loss: 0.6931
# Epoch 92/100, Loss: 0.6931
# Epoch 93/100, Loss: 0.6931
# Epoch 94/100, Loss: 0.6931
# Epoch 95/100, Loss: 0.6931
# Epoch 96/100, Loss: 0.6931
# Epoch 97/100, Loss: 0.6931
# Epoch 98/100, Loss: 0.6931
# Epoch 99/100, Loss: 0.6931
# Epoch 100/100, Loss: 0.6931
# Test Precision: 0.0000
# Test Recall: 0.0000
# Test F1 Score: 0.0000
# Test ROC-AUC Score: 0.4918
# Test AUPRC Score: 0.0631
# Confusion Matrix:
# [[660   0]
#  [ 50   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.93      1.00      0.96       660
#          1.0       0.00      0.00      0.00        50
#
#     accuracy                           0.93       710
#    macro avg       0.46      0.50      0.48       710
# weighted avg       0.86      0.93      0.90       710
#
# Fold 3
# Training with learning rate: 0.001, dropout: 0.2, channels: 64, kernel size: 3
# c:\Users\Grego\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Grego\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Grego\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Grego\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Found new best hyperparameters: (0.001, 0.2, 64, 3)
# Training with learning rate: 0.001, dropout: 0.2, channels: 64, kernel size: 5
# Training with learning rate: 0.001, dropout: 0.2, channels: 128, kernel size: 3
# Found new best hyperparameters: (0.001, 0.2, 128, 3)
# Training with learning rate: 0.001, dropout: 0.2, channels: 128, kernel size: 5
# Training with learning rate: 0.001, dropout: 0.5, channels: 64, kernel size: 3
# Training with learning rate: 0.001, dropout: 0.5, channels: 64, kernel size: 5
# Found new best hyperparameters: (0.001, 0.5, 64, 5)
# Training with learning rate: 0.001, dropout: 0.5, channels: 128, kernel size: 3
# Training with learning rate: 0.001, dropout: 0.5, channels: 128, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.2, channels: 64, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.2, channels: 64, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.2, channels: 128, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.2, channels: 128, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.5, channels: 64, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.5, channels: 64, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.5, channels: 128, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.5, channels: 128, kernel size: 5
# Best Hyperparameters for Fold 3: (0.001, 0.5, 64, 5)
# Training on full training set with best hyperparameters: (0.001, 0.5, 64, 5)
# Epoch 1/100, Loss: 0.7383
# Epoch 2/100, Loss: 0.6949
# Epoch 3/100, Loss: 0.6938
# Epoch 4/100, Loss: 0.6935
# Epoch 5/100, Loss: 0.6934
# Epoch 6/100, Loss: 0.6933
# Epoch 7/100, Loss: 0.6933
# Epoch 8/100, Loss: 0.6932
# Epoch 9/100, Loss: 0.6932
# Epoch 10/100, Loss: 0.6932
# Epoch 11/100, Loss: 0.6932
# Epoch 12/100, Loss: 0.6932
# Epoch 13/100, Loss: 0.6932
# Epoch 14/100, Loss: 0.6932
# Epoch 15/100, Loss: 0.6932
# Epoch 16/100, Loss: 0.6932
# Epoch 17/100, Loss: 0.6932
# Epoch 18/100, Loss: 0.6932
# Epoch 19/100, Loss: 0.6932
# Epoch 20/100, Loss: 0.6932
# Epoch 21/100, Loss: 0.6932
# Epoch 22/100, Loss: 0.6932
# Epoch 23/100, Loss: 0.6932
# Epoch 24/100, Loss: 0.6932
# Epoch 25/100, Loss: 0.6932
# Epoch 26/100, Loss: 0.6932
# Epoch 27/100, Loss: 0.6932
# Epoch 28/100, Loss: 0.6931
# Epoch 29/100, Loss: 0.6931
# Epoch 30/100, Loss: 0.6931
# Epoch 31/100, Loss: 0.6931
# Epoch 32/100, Loss: 0.6931
# Epoch 33/100, Loss: 0.6931
# Epoch 34/100, Loss: 0.6931
# Epoch 35/100, Loss: 0.6931
# Epoch 36/100, Loss: 0.6931
# Epoch 37/100, Loss: 0.6931
# Epoch 38/100, Loss: 0.6931
# Epoch 39/100, Loss: 0.6931
# Epoch 40/100, Loss: 0.6931
# Epoch 41/100, Loss: 0.6931
# Epoch 42/100, Loss: 0.6931
# Epoch 43/100, Loss: 0.6931
# Epoch 44/100, Loss: 0.6931
# Epoch 45/100, Loss: 0.6930
# Epoch 46/100, Loss: 0.6930
# Epoch 47/100, Loss: 0.6930
# Epoch 48/100, Loss: 0.6931
# Epoch 49/100, Loss: 0.6930
# Epoch 50/100, Loss: 0.6929
# Epoch 51/100, Loss: 0.6930
# Epoch 52/100, Loss: 0.6931
# Epoch 53/100, Loss: 0.6930
# Epoch 54/100, Loss: 0.6929
# Epoch 55/100, Loss: 0.6929
# Epoch 56/100, Loss: 0.6929
# Epoch 57/100, Loss: 0.6929
# Epoch 58/100, Loss: 0.6928
# Epoch 59/100, Loss: 0.6929
# Epoch 60/100, Loss: 0.6929
# Epoch 61/100, Loss: 0.6928
# Epoch 62/100, Loss: 0.6928
# Epoch 63/100, Loss: 0.6929
# Epoch 64/100, Loss: 0.6927
# Epoch 65/100, Loss: 0.6928
# Epoch 66/100, Loss: 0.6928
# Epoch 67/100, Loss: 0.6928
# Epoch 68/100, Loss: 0.6929
# Epoch 69/100, Loss: 0.6928
# Epoch 70/100, Loss: 0.6927
# Epoch 71/100, Loss: 0.6927
# Epoch 72/100, Loss: 0.6928
# Epoch 73/100, Loss: 0.6928
# Epoch 74/100, Loss: 0.6928
# Epoch 75/100, Loss: 0.6927
# Epoch 76/100, Loss: 0.6927
# Epoch 77/100, Loss: 0.6927
# Epoch 78/100, Loss: 0.6927
# Epoch 79/100, Loss: 0.6927
# Epoch 80/100, Loss: 0.6927
# Epoch 81/100, Loss: 0.6928
# Epoch 82/100, Loss: 0.6927
# Epoch 83/100, Loss: 0.6926
# Epoch 84/100, Loss: 0.6926
# Epoch 85/100, Loss: 0.6927
# Epoch 86/100, Loss: 0.6926
# Epoch 87/100, Loss: 0.6926
# Epoch 88/100, Loss: 0.6926
# Epoch 89/100, Loss: 0.6926
# Epoch 90/100, Loss: 0.6926
# Epoch 91/100, Loss: 0.6926
# Epoch 92/100, Loss: 0.6926
# Epoch 93/100, Loss: 0.6926
# Epoch 94/100, Loss: 0.6926
# Epoch 95/100, Loss: 0.6926
# Epoch 96/100, Loss: 0.6926
# Epoch 97/100, Loss: 0.6926
# Epoch 98/100, Loss: 0.6926
# Epoch 99/100, Loss: 0.6925
# Epoch 100/100, Loss: 0.6925
# Test Precision: 0.0000
# Test Recall: 0.0000
# Test F1 Score: 0.0000
# Test ROC-AUC Score: 0.5165
# Test AUPRC Score: 0.0681
# Confusion Matrix:
# [[662   0]
#  [ 48   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.93      1.00      0.97       662
#          1.0       0.00      0.00      0.00        48
#
#     accuracy                           0.93       710
#    macro avg       0.47      0.50      0.48       710
# weighted avg       0.87      0.93      0.90       710
#
# Fold 4
# Training with learning rate: 0.001, dropout: 0.2, channels: 64, kernel size: 3
# c:\Users\Grego\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Grego\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Grego\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Grego\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Found new best hyperparameters: (0.001, 0.2, 64, 3)
# Training with learning rate: 0.001, dropout: 0.2, channels: 64, kernel size: 5
# Found new best hyperparameters: (0.001, 0.2, 64, 5)
# Training with learning rate: 0.001, dropout: 0.2, channels: 128, kernel size: 3
# Training with learning rate: 0.001, dropout: 0.2, channels: 128, kernel size: 5
# Training with learning rate: 0.001, dropout: 0.5, channels: 64, kernel size: 3
# Training with learning rate: 0.001, dropout: 0.5, channels: 64, kernel size: 5
# Training with learning rate: 0.001, dropout: 0.5, channels: 128, kernel size: 3
# Training with learning rate: 0.001, dropout: 0.5, channels: 128, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.2, channels: 64, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.2, channels: 64, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.2, channels: 128, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.2, channels: 128, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.5, channels: 64, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.5, channels: 64, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.5, channels: 128, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.5, channels: 128, kernel size: 5
# Best Hyperparameters for Fold 4: (0.001, 0.2, 64, 5)
# Training on full training set with best hyperparameters: (0.001, 0.2, 64, 5)
# Epoch 1/100, Loss: 0.7290
# Epoch 2/100, Loss: 0.6942
# Epoch 3/100, Loss: 0.6936
# Epoch 4/100, Loss: 0.6934
# Epoch 5/100, Loss: 0.6933
# Epoch 6/100, Loss: 0.6932
# Epoch 7/100, Loss: 0.6932
# Epoch 8/100, Loss: 0.6932
# Epoch 9/100, Loss: 0.6932
# Epoch 10/100, Loss: 0.6932
# Epoch 11/100, Loss: 0.6932
# Epoch 12/100, Loss: 0.6932
# Epoch 13/100, Loss: 0.6932
# Epoch 14/100, Loss: 0.6932
# Epoch 15/100, Loss: 0.6932
# Epoch 16/100, Loss: 0.6932
# Epoch 17/100, Loss: 0.6932
# Epoch 18/100, Loss: 0.6932
# Epoch 19/100, Loss: 0.6932
# Epoch 20/100, Loss: 0.6932
# Epoch 21/100, Loss: 0.6932
# Epoch 22/100, Loss: 0.6932
# Epoch 23/100, Loss: 0.6932
# Epoch 24/100, Loss: 0.6932
# Epoch 25/100, Loss: 0.6932
# Epoch 26/100, Loss: 0.6931
# Epoch 27/100, Loss: 0.6931
# Epoch 28/100, Loss: 0.6931
# Epoch 29/100, Loss: 0.6931
# Epoch 30/100, Loss: 0.6931
# Epoch 31/100, Loss: 0.6931
# Epoch 32/100, Loss: 0.6930
# Epoch 33/100, Loss: 0.6929
# Epoch 34/100, Loss: 0.6929
# Epoch 35/100, Loss: 0.6929
# Epoch 36/100, Loss: 0.6929
# Epoch 37/100, Loss: 0.6929
# Epoch 38/100, Loss: 0.6928
# Epoch 39/100, Loss: 0.6928
# Epoch 40/100, Loss: 0.6928
# Epoch 41/100, Loss: 0.6928
# Epoch 42/100, Loss: 0.6928
# Epoch 43/100, Loss: 0.6927
# Epoch 44/100, Loss: 0.6927
# Epoch 45/100, Loss: 0.6927
# Epoch 46/100, Loss: 0.6927
# Epoch 47/100, Loss: 0.6927
# Epoch 48/100, Loss: 0.6927
# Epoch 49/100, Loss: 0.6927
# Epoch 50/100, Loss: 0.6927
# Epoch 51/100, Loss: 0.6927
# Epoch 52/100, Loss: 0.6927
# Epoch 53/100, Loss: 0.6927
# Epoch 54/100, Loss: 0.6927
# Epoch 55/100, Loss: 0.6926
# Epoch 56/100, Loss: 0.6926
# Epoch 57/100, Loss: 0.6926
# Epoch 58/100, Loss: 0.6926
# Epoch 59/100, Loss: 0.6926
# Epoch 60/100, Loss: 0.6926
# Epoch 61/100, Loss: 0.6926
# Epoch 62/100, Loss: 0.6926
# Epoch 63/100, Loss: 0.6926
# Epoch 64/100, Loss: 0.6926
# Epoch 65/100, Loss: 0.6926
# Epoch 66/100, Loss: 0.6926
# Epoch 67/100, Loss: 0.6926
# Epoch 68/100, Loss: 0.6926
# Epoch 69/100, Loss: 0.6926
# Epoch 70/100, Loss: 0.6926
# Epoch 71/100, Loss: 0.6926
# Epoch 72/100, Loss: 0.6926
# Epoch 73/100, Loss: 0.6926
# Epoch 74/100, Loss: 0.6926
# Epoch 75/100, Loss: 0.6926
# Epoch 76/100, Loss: 0.6926
# Epoch 77/100, Loss: 0.6926
# Epoch 78/100, Loss: 0.6926
# Epoch 79/100, Loss: 0.6926
# Epoch 80/100, Loss: 0.6926
# Epoch 81/100, Loss: 0.6926
# Epoch 82/100, Loss: 0.6926
# Epoch 83/100, Loss: 0.6926
# Epoch 84/100, Loss: 0.6926
# Epoch 85/100, Loss: 0.6926
# Epoch 86/100, Loss: 0.6926
# Epoch 87/100, Loss: 0.6926
# Epoch 88/100, Loss: 0.6926
# Epoch 89/100, Loss: 0.6926
# Epoch 90/100, Loss: 0.6926
# Epoch 91/100, Loss: 0.6927
# Epoch 92/100, Loss: 0.6926
# Epoch 93/100, Loss: 0.6926
# Epoch 94/100, Loss: 0.6926
# Epoch 95/100, Loss: 0.6926
# Epoch 96/100, Loss: 0.6926
# Epoch 97/100, Loss: 0.6926
# Epoch 98/100, Loss: 0.6926
# Epoch 99/100, Loss: 0.6926
# Epoch 100/100, Loss: 0.6925
# Test Precision: 0.0000
# Test Recall: 0.0000
# Test F1 Score: 0.0000
# Test ROC-AUC Score: 0.5217
# Test AUPRC Score: 0.1149
# Confusion Matrix:
# [[668   0]
#  [ 42   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.94      1.00      0.97       668
#          1.0       0.00      0.00      0.00        42
#
#     accuracy                           0.94       710
#    macro avg       0.47      0.50      0.48       710
# weighted avg       0.89      0.94      0.91       710
#
# Fold 5
# Training with learning rate: 0.001, dropout: 0.2, channels: 64, kernel size: 3
# c:\Users\Grego\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Grego\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Grego\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Grego\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Found new best hyperparameters: (0.001, 0.2, 64, 3)
# Training with learning rate: 0.001, dropout: 0.2, channels: 64, kernel size: 5
# Found new best hyperparameters: (0.001, 0.2, 64, 5)
# Training with learning rate: 0.001, dropout: 0.2, channels: 128, kernel size: 3
# Training with learning rate: 0.001, dropout: 0.2, channels: 128, kernel size: 5
# Training with learning rate: 0.001, dropout: 0.5, channels: 64, kernel size: 3
# Training with learning rate: 0.001, dropout: 0.5, channels: 64, kernel size: 5
# Found new best hyperparameters: (0.001, 0.5, 64, 5)
# Training with learning rate: 0.001, dropout: 0.5, channels: 128, kernel size: 3
# Training with learning rate: 0.001, dropout: 0.5, channels: 128, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.2, channels: 64, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.2, channels: 64, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.2, channels: 128, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.2, channels: 128, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.5, channels: 64, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.5, channels: 64, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.5, channels: 128, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.5, channels: 128, kernel size: 5
# Best Hyperparameters for Fold 5: (0.001, 0.5, 64, 5)
# Training on full training set with best hyperparameters: (0.001, 0.5, 64, 5)
# Epoch 1/100, Loss: 0.7362
# Epoch 2/100, Loss: 0.6948
# Epoch 3/100, Loss: 0.6938
# Epoch 4/100, Loss: 0.6935
# Epoch 5/100, Loss: 0.6934
# Epoch 6/100, Loss: 0.6933
# Epoch 7/100, Loss: 0.6933
# Epoch 8/100, Loss: 0.6932
# Epoch 9/100, Loss: 0.6932
# Epoch 10/100, Loss: 0.6932
# Epoch 11/100, Loss: 0.6932
# Epoch 12/100, Loss: 0.6932
# Epoch 13/100, Loss: 0.6932
# Epoch 14/100, Loss: 0.6932
# Epoch 15/100, Loss: 0.6932
# Epoch 16/100, Loss: 0.6931
# Epoch 17/100, Loss: 0.6931
# Epoch 18/100, Loss: 0.6931
# Epoch 19/100, Loss: 0.6931
# Epoch 20/100, Loss: 0.6931
# Epoch 21/100, Loss: 0.6930
# Epoch 22/100, Loss: 0.6929
# Epoch 23/100, Loss: 0.6929
# Epoch 24/100, Loss: 0.6929
# Epoch 25/100, Loss: 0.6928
# Epoch 26/100, Loss: 0.6928
# Epoch 27/100, Loss: 0.6929
# Epoch 28/100, Loss: 0.6927
# Epoch 29/100, Loss: 0.6927
# Epoch 30/100, Loss: 0.6927
# Epoch 31/100, Loss: 0.6927
# Epoch 32/100, Loss: 0.6927
# Epoch 33/100, Loss: 0.6926
# Epoch 34/100, Loss: 0.6925
# Epoch 35/100, Loss: 0.6925
# Epoch 36/100, Loss: 0.6924
# Epoch 37/100, Loss: 0.6924
# Epoch 38/100, Loss: 0.6924
# Epoch 39/100, Loss: 0.6922
# Epoch 40/100, Loss: 0.6922
# Epoch 41/100, Loss: 0.6921
# Epoch 42/100, Loss: 0.6920
# Epoch 43/100, Loss: 0.6920
# Epoch 44/100, Loss: 0.6920
# Epoch 45/100, Loss: 0.6921
# Epoch 46/100, Loss: 0.6920
# Epoch 47/100, Loss: 0.6920
# Epoch 48/100, Loss: 0.6919
# Epoch 49/100, Loss: 0.6919
# Epoch 50/100, Loss: 0.6919
# Epoch 51/100, Loss: 0.6918
# Epoch 52/100, Loss: 0.6918
# Epoch 53/100, Loss: 0.6919
# Epoch 54/100, Loss: 0.6918
# Epoch 55/100, Loss: 0.6917
# Epoch 56/100, Loss: 0.6917
# Epoch 57/100, Loss: 0.6918
# Epoch 58/100, Loss: 0.6917
# Epoch 59/100, Loss: 0.6917
# Epoch 60/100, Loss: 0.6917
# Epoch 61/100, Loss: 0.6917
# Epoch 62/100, Loss: 0.6915
# Epoch 63/100, Loss: 0.6916
# Epoch 64/100, Loss: 0.6916
# Epoch 65/100, Loss: 0.6915
# Epoch 66/100, Loss: 0.6915
# Epoch 67/100, Loss: 0.6915
# Epoch 68/100, Loss: 0.6916
# Epoch 69/100, Loss: 0.6916
# Epoch 70/100, Loss: 0.6916
# Epoch 71/100, Loss: 0.6914
# Epoch 72/100, Loss: 0.6916
# Epoch 73/100, Loss: 0.6914
# Epoch 74/100, Loss: 0.6913
# Epoch 75/100, Loss: 0.6913
# Epoch 76/100, Loss: 0.6913
# Epoch 77/100, Loss: 0.6913
# Epoch 78/100, Loss: 0.6912
# Epoch 79/100, Loss: 0.6912
# Epoch 80/100, Loss: 0.6913
# Epoch 81/100, Loss: 0.6911
# Epoch 82/100, Loss: 0.6912
# Epoch 83/100, Loss: 0.6913
# Epoch 84/100, Loss: 0.6912
# Epoch 85/100, Loss: 0.6911
# Epoch 86/100, Loss: 0.6911
# Epoch 87/100, Loss: 0.6910
# Epoch 88/100, Loss: 0.6912
# Epoch 89/100, Loss: 0.6910
# Epoch 90/100, Loss: 0.6909
# Epoch 91/100, Loss: 0.6909
# Epoch 92/100, Loss: 0.6909
# Epoch 93/100, Loss: 0.6910
# Epoch 94/100, Loss: 0.6910
# Epoch 95/100, Loss: 0.6911
# Epoch 96/100, Loss: 0.6909
# Epoch 97/100, Loss: 0.6908
# Epoch 98/100, Loss: 0.6908
# Epoch 99/100, Loss: 0.6908
# Epoch 100/100, Loss: 0.6908
# Test Precision: 0.0000
# Test Recall: 0.0000
# Test F1 Score: 0.0000
# Test ROC-AUC Score: 0.6597
# Test AUPRC Score: 0.1069
# Confusion Matrix:
# [[665   2]
#  [ 43   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.94      1.00      0.97       667
#          1.0       0.00      0.00      0.00        43
#
#     accuracy                           0.94       710
#    macro avg       0.47      0.50      0.48       710
# weighted avg       0.88      0.94      0.91       710
#
# Fold 6
# Training with learning rate: 0.001, dropout: 0.2, channels: 64, kernel size: 3
# Found new best hyperparameters: (0.001, 0.2, 64, 3)
# Training with learning rate: 0.001, dropout: 0.2, channels: 64, kernel size: 5
# Training with learning rate: 0.001, dropout: 0.2, channels: 128, kernel size: 3
# Training with learning rate: 0.001, dropout: 0.2, channels: 128, kernel size: 5
# Training with learning rate: 0.001, dropout: 0.5, channels: 64, kernel size: 3
# Training with learning rate: 0.001, dropout: 0.5, channels: 64, kernel size: 5
# Training with learning rate: 0.001, dropout: 0.5, channels: 128, kernel size: 3
# Training with learning rate: 0.001, dropout: 0.5, channels: 128, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.2, channels: 64, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.2, channels: 64, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.2, channels: 128, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.2, channels: 128, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.5, channels: 64, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.5, channels: 64, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.5, channels: 128, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.5, channels: 128, kernel size: 5
# Best Hyperparameters for Fold 6: (0.001, 0.2, 64, 3)
# Training on full training set with best hyperparameters: (0.001, 0.2, 64, 3)
# Epoch 1/100, Loss: 0.7217
# Epoch 2/100, Loss: 0.6940
# Epoch 3/100, Loss: 0.6935
# Epoch 4/100, Loss: 0.6933
# Epoch 5/100, Loss: 0.6932
# Epoch 6/100, Loss: 0.6932
# Epoch 7/100, Loss: 0.6932
# Epoch 8/100, Loss: 0.6932
# Epoch 9/100, Loss: 0.6932
# Epoch 10/100, Loss: 0.6932
# Epoch 11/100, Loss: 0.6932
# Epoch 12/100, Loss: 0.6932
# Epoch 13/100, Loss: 0.6932
# Epoch 14/100, Loss: 0.6932
# Epoch 15/100, Loss: 0.6932
# Epoch 16/100, Loss: 0.6932
# Epoch 17/100, Loss: 0.6932
# Epoch 18/100, Loss: 0.6932
# Epoch 19/100, Loss: 0.6932
# Epoch 20/100, Loss: 0.6932
# Epoch 21/100, Loss: 0.6932
# Epoch 22/100, Loss: 0.6932
# Epoch 23/100, Loss: 0.6932
# Epoch 24/100, Loss: 0.6931
# Epoch 25/100, Loss: 0.6931
# Epoch 26/100, Loss: 0.6931
# Epoch 27/100, Loss: 0.6931
# Epoch 28/100, Loss: 0.6931
# Epoch 29/100, Loss: 0.6931
# Epoch 30/100, Loss: 0.6931
# Epoch 31/100, Loss: 0.6931
# Epoch 32/100, Loss: 0.6931
# Epoch 33/100, Loss: 0.6931
# Epoch 34/100, Loss: 0.6931
# Epoch 35/100, Loss: 0.6931
# Epoch 36/100, Loss: 0.6931
# Epoch 37/100, Loss: 0.6931
# Epoch 38/100, Loss: 0.6931
# Epoch 39/100, Loss: 0.6931
# Epoch 40/100, Loss: 0.6931
# Epoch 41/100, Loss: 0.6931
# Epoch 42/100, Loss: 0.6931
# Epoch 43/100, Loss: 0.6931
# Epoch 44/100, Loss: 0.6931
# Epoch 45/100, Loss: 0.6931
# Epoch 46/100, Loss: 0.6931
# Epoch 47/100, Loss: 0.6931
# Epoch 48/100, Loss: 0.6931
# Epoch 49/100, Loss: 0.6931
# Epoch 50/100, Loss: 0.6931
# Epoch 51/100, Loss: 0.6931
# Epoch 52/100, Loss: 0.6931
# Epoch 53/100, Loss: 0.6931
# Epoch 54/100, Loss: 0.6931
# Epoch 55/100, Loss: 0.6931
# Epoch 56/100, Loss: 0.6931
# Epoch 57/100, Loss: 0.6931
# Epoch 58/100, Loss: 0.6931
# Epoch 59/100, Loss: 0.6931
# Epoch 60/100, Loss: 0.6931
# Epoch 61/100, Loss: 0.6931
# Epoch 62/100, Loss: 0.6931
# Epoch 63/100, Loss: 0.6931
# Epoch 64/100, Loss: 0.6931
# Epoch 65/100, Loss: 0.6931
# Epoch 66/100, Loss: 0.6931
# Epoch 67/100, Loss: 0.6931
# Epoch 68/100, Loss: 0.6931
# Epoch 69/100, Loss: 0.6931
# Epoch 70/100, Loss: 0.6931
# Epoch 71/100, Loss: 0.6931
# Epoch 72/100, Loss: 0.6931
# Epoch 73/100, Loss: 0.6931
# Epoch 74/100, Loss: 0.6931
# Epoch 75/100, Loss: 0.6931
# Epoch 76/100, Loss: 0.6931
# Epoch 77/100, Loss: 0.6931
# Epoch 78/100, Loss: 0.6931
# Epoch 79/100, Loss: 0.6931
# Epoch 80/100, Loss: 0.6931
# Epoch 81/100, Loss: 0.6931
# Epoch 82/100, Loss: 0.6931
# Epoch 83/100, Loss: 0.6931
# Epoch 84/100, Loss: 0.6931
# Epoch 85/100, Loss: 0.6931
# Epoch 86/100, Loss: 0.6931
# Epoch 87/100, Loss: 0.6931
# Epoch 88/100, Loss: 0.6931
# Epoch 89/100, Loss: 0.6931
# Epoch 90/100, Loss: 0.6931
# Epoch 91/100, Loss: 0.6931
# Epoch 92/100, Loss: 0.6931
# Epoch 93/100, Loss: 0.6931
# Epoch 94/100, Loss: 0.6931
# Epoch 95/100, Loss: 0.6931
# Epoch 96/100, Loss: 0.6931
# Epoch 97/100, Loss: 0.6931
# Epoch 98/100, Loss: 0.6931
# Epoch 99/100, Loss: 0.6931
# Epoch 100/100, Loss: 0.6931
# Test Precision: 0.0000
# Test Recall: 0.0000
# Test F1 Score: 0.0000
# Test ROC-AUC Score: 0.4025
# Test AUPRC Score: 0.0378
# Confusion Matrix:
# [[680   0]
#  [ 30   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.96      1.00      0.98       680
#          1.0       0.00      0.00      0.00        30
#
#     accuracy                           0.96       710
#    macro avg       0.48      0.50      0.49       710
# weighted avg       0.92      0.96      0.94       710
#
# Fold 7
# Training with learning rate: 0.001, dropout: 0.2, channels: 64, kernel size: 3
# c:\Users\Grego\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Grego\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Grego\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Grego\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Found new best hyperparameters: (0.001, 0.2, 64, 3)
# Training with learning rate: 0.001, dropout: 0.2, channels: 64, kernel size: 5
# Training with learning rate: 0.001, dropout: 0.2, channels: 128, kernel size: 3
# Found new best hyperparameters: (0.001, 0.2, 128, 3)
# Training with learning rate: 0.001, dropout: 0.2, channels: 128, kernel size: 5
# Found new best hyperparameters: (0.001, 0.2, 128, 5)
# Training with learning rate: 0.001, dropout: 0.5, channels: 64, kernel size: 3
# Training with learning rate: 0.001, dropout: 0.5, channels: 64, kernel size: 5
# Training with learning rate: 0.001, dropout: 0.5, channels: 128, kernel size: 3
# Training with learning rate: 0.001, dropout: 0.5, channels: 128, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.2, channels: 64, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.2, channels: 64, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.2, channels: 128, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.2, channels: 128, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.5, channels: 64, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.5, channels: 64, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.5, channels: 128, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.5, channels: 128, kernel size: 5
# Best Hyperparameters for Fold 7: (0.001, 0.2, 128, 5)
# Training on full training set with best hyperparameters: (0.001, 0.2, 128, 5)
# Epoch 1/100, Loss: 0.7149
# Epoch 2/100, Loss: 0.6936
# Epoch 3/100, Loss: 0.6933
# Epoch 4/100, Loss: 0.6932
# Epoch 5/100, Loss: 0.6932
# Epoch 6/100, Loss: 0.6932
# Epoch 7/100, Loss: 0.6932
# Epoch 8/100, Loss: 0.6932
# Epoch 9/100, Loss: 0.6932
# Epoch 10/100, Loss: 0.6932
# Epoch 11/100, Loss: 0.6932
# Epoch 12/100, Loss: 0.6932
# Epoch 13/100, Loss: 0.6931
# Epoch 14/100, Loss: 0.6931
# Epoch 15/100, Loss: 0.6931
# Epoch 16/100, Loss: 0.6931
# Epoch 17/100, Loss: 0.6930
# Epoch 18/100, Loss: 0.6929
# Epoch 19/100, Loss: 0.6929
# Epoch 20/100, Loss: 0.6927
# Epoch 21/100, Loss: 0.6927
# Epoch 22/100, Loss: 0.6927
# Epoch 23/100, Loss: 0.6926
# Epoch 24/100, Loss: 0.6925
# Epoch 25/100, Loss: 0.6924
# Epoch 26/100, Loss: 0.6924
# Epoch 27/100, Loss: 0.6923
# Epoch 28/100, Loss: 0.6923
# Epoch 29/100, Loss: 0.6921
# Epoch 30/100, Loss: 0.6922
# Epoch 31/100, Loss: 0.6921
# Epoch 32/100, Loss: 0.6921
# Epoch 33/100, Loss: 0.6920
# Epoch 34/100, Loss: 0.6919
# Epoch 35/100, Loss: 0.6919
# Epoch 36/100, Loss: 0.6918
# Epoch 37/100, Loss: 0.6919
# Epoch 38/100, Loss: 0.6918
# Epoch 39/100, Loss: 0.6917
# Epoch 40/100, Loss: 0.6916
# Epoch 41/100, Loss: 0.6917
# Epoch 42/100, Loss: 0.6918
# Epoch 43/100, Loss: 0.6916
# Epoch 44/100, Loss: 0.6914
# Epoch 45/100, Loss: 0.6914
# Epoch 46/100, Loss: 0.6914
# Epoch 47/100, Loss: 0.6912
# Epoch 48/100, Loss: 0.6910
# Epoch 49/100, Loss: 0.6910
# Epoch 50/100, Loss: 0.6910
# Epoch 51/100, Loss: 0.6910
# Epoch 52/100, Loss: 0.6910
# Epoch 53/100, Loss: 0.6910
# Epoch 54/100, Loss: 0.6909
# Epoch 55/100, Loss: 0.6910
# Epoch 56/100, Loss: 0.6909
# Epoch 57/100, Loss: 0.6909
# Epoch 58/100, Loss: 0.6908
# Epoch 59/100, Loss: 0.6908
# Epoch 60/100, Loss: 0.6907
# Epoch 61/100, Loss: 0.6907
# Epoch 62/100, Loss: 0.6907
# Epoch 63/100, Loss: 0.6909
# Epoch 64/100, Loss: 0.6907
# Epoch 65/100, Loss: 0.6907
# Epoch 66/100, Loss: 0.6908
# Epoch 67/100, Loss: 0.6907
# Epoch 68/100, Loss: 0.6907
# Epoch 69/100, Loss: 0.6906
# Epoch 70/100, Loss: 0.6906
# Epoch 71/100, Loss: 0.6907
# Epoch 72/100, Loss: 0.6906
# Epoch 73/100, Loss: 0.6906
# Epoch 74/100, Loss: 0.6906
# Epoch 75/100, Loss: 0.6906
# Epoch 76/100, Loss: 0.6906
# Epoch 77/100, Loss: 0.6906
# Epoch 78/100, Loss: 0.6906
# Epoch 79/100, Loss: 0.6906
# Epoch 80/100, Loss: 0.6905
# Epoch 81/100, Loss: 0.6909
# Epoch 82/100, Loss: 0.6907
# Epoch 83/100, Loss: 0.6908
# Epoch 84/100, Loss: 0.6906
# Epoch 85/100, Loss: 0.6905
# Epoch 86/100, Loss: 0.6905
# Epoch 87/100, Loss: 0.6905
# Epoch 88/100, Loss: 0.6905
# Epoch 89/100, Loss: 0.6909
# Epoch 90/100, Loss: 0.6906
# Epoch 91/100, Loss: 0.6907
# Epoch 92/100, Loss: 0.6907
# Epoch 93/100, Loss: 0.6906
# Epoch 94/100, Loss: 0.6906
# Epoch 95/100, Loss: 0.6905
# Epoch 96/100, Loss: 0.6906
# Epoch 97/100, Loss: 0.6904
# Epoch 98/100, Loss: 0.6904
# Epoch 99/100, Loss: 0.6904
# Epoch 100/100, Loss: 0.6905
# Test Precision: 0.0000
# Test Recall: 0.0000
# Test F1 Score: 0.0000
# Test ROC-AUC Score: 0.5687
# Test AUPRC Score: 0.0802
# Confusion Matrix:
# [[670   1]
#  [ 39   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.94      1.00      0.97       671
#          1.0       0.00      0.00      0.00        39
#
#     accuracy                           0.94       710
#    macro avg       0.47      0.50      0.49       710
# weighted avg       0.89      0.94      0.92       710
#
# Fold 8
# Training with learning rate: 0.001, dropout: 0.2, channels: 64, kernel size: 3
# Found new best hyperparameters: (0.001, 0.2, 64, 3)
# Training with learning rate: 0.001, dropout: 0.2, channels: 64, kernel size: 5
# Found new best hyperparameters: (0.001, 0.2, 64, 5)
# Training with learning rate: 0.001, dropout: 0.2, channels: 128, kernel size: 3
# Training with learning rate: 0.001, dropout: 0.2, channels: 128, kernel size: 5
# Training with learning rate: 0.001, dropout: 0.5, channels: 64, kernel size: 3
# Training with learning rate: 0.001, dropout: 0.5, channels: 64, kernel size: 5
# Training with learning rate: 0.001, dropout: 0.5, channels: 128, kernel size: 3
# Training with learning rate: 0.001, dropout: 0.5, channels: 128, kernel size: 5
# Found new best hyperparameters: (0.001, 0.5, 128, 5)
# Training with learning rate: 0.01, dropout: 0.2, channels: 64, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.2, channels: 64, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.2, channels: 128, kernel size: 3
# Found new best hyperparameters: (0.01, 0.2, 128, 3)
# Training with learning rate: 0.01, dropout: 0.2, channels: 128, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.5, channels: 64, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.5, channels: 64, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.5, channels: 128, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.5, channels: 128, kernel size: 5
# Best Hyperparameters for Fold 8: (0.01, 0.2, 128, 3)
# Training on full training set with best hyperparameters: (0.01, 0.2, 128, 3)
# Epoch 1/100, Loss: 0.6950
# Epoch 2/100, Loss: 0.6931
# Epoch 3/100, Loss: 0.6931
# Epoch 4/100, Loss: 0.6931
# Epoch 5/100, Loss: 0.6931
# Epoch 6/100, Loss: 0.6931
# Epoch 7/100, Loss: 0.6931
# Epoch 8/100, Loss: 0.6931
# Epoch 9/100, Loss: 0.6931
# Epoch 10/100, Loss: 0.6931
# Epoch 11/100, Loss: 0.6931
# Epoch 12/100, Loss: 0.6931
# Epoch 13/100, Loss: 0.6931
# Epoch 14/100, Loss: 0.6931
# Epoch 15/100, Loss: 0.6931
# Epoch 16/100, Loss: 0.6931
# Epoch 17/100, Loss: 0.6931
# Epoch 18/100, Loss: 0.6931
# Epoch 19/100, Loss: 0.6931
# Epoch 20/100, Loss: 0.6931
# Epoch 21/100, Loss: 0.6931
# Epoch 22/100, Loss: 0.6931
# Epoch 23/100, Loss: 0.6931
# Epoch 24/100, Loss: 0.6931
# Epoch 25/100, Loss: 0.6931
# Epoch 26/100, Loss: 0.6931
# Epoch 27/100, Loss: 0.6931
# Epoch 28/100, Loss: 0.6931
# Epoch 29/100, Loss: 0.6931
# Epoch 30/100, Loss: 0.6931
# Epoch 31/100, Loss: 0.6931
# Epoch 32/100, Loss: 0.6931
# Epoch 33/100, Loss: 0.6931
# Epoch 34/100, Loss: 0.6931
# Epoch 35/100, Loss: 0.6931
# Epoch 36/100, Loss: 0.6931
# Epoch 37/100, Loss: 0.6931
# Epoch 38/100, Loss: 0.6931
# Epoch 39/100, Loss: 0.6931
# Epoch 40/100, Loss: 0.6931
# Epoch 41/100, Loss: 0.6931
# Epoch 42/100, Loss: 0.6931
# Epoch 43/100, Loss: 0.6931
# Epoch 44/100, Loss: 0.6931
# Epoch 45/100, Loss: 0.6931
# Epoch 46/100, Loss: 0.6931
# Epoch 47/100, Loss: 0.6931
# Epoch 48/100, Loss: 0.6931
# Epoch 49/100, Loss: 0.6931
# Epoch 50/100, Loss: 0.6931
# Epoch 51/100, Loss: 0.6931
# Epoch 52/100, Loss: 0.6931
# Epoch 53/100, Loss: 0.6931
# Epoch 54/100, Loss: 0.6931
# Epoch 55/100, Loss: 0.6931
# Epoch 56/100, Loss: 0.6931
# Epoch 57/100, Loss: 0.6931
# Epoch 58/100, Loss: 0.6931
# Epoch 59/100, Loss: 0.6931
# Epoch 60/100, Loss: 0.6931
# Epoch 61/100, Loss: 0.6931
# Epoch 62/100, Loss: 0.6931
# Epoch 63/100, Loss: 0.6931
# Epoch 64/100, Loss: 0.6931
# Epoch 65/100, Loss: 0.6931
# Epoch 66/100, Loss: 0.6931
# Epoch 67/100, Loss: 0.6931
# Epoch 68/100, Loss: 0.6931
# Epoch 69/100, Loss: 0.6931
# Epoch 70/100, Loss: 0.6931
# Epoch 71/100, Loss: 0.6931
# Epoch 72/100, Loss: 0.6931
# Epoch 73/100, Loss: 0.6931
# Epoch 74/100, Loss: 0.6931
# Epoch 75/100, Loss: 0.6931
# Epoch 76/100, Loss: 0.6931
# Epoch 77/100, Loss: 0.6931
# Epoch 78/100, Loss: 0.6931
# Epoch 79/100, Loss: 0.6931
# Epoch 80/100, Loss: 0.6931
# Epoch 81/100, Loss: 0.6931
# Epoch 82/100, Loss: 0.6931
# Epoch 83/100, Loss: 0.6931
# Epoch 84/100, Loss: 0.6931
# Epoch 85/100, Loss: 0.6931
# Epoch 86/100, Loss: 0.6931
# Epoch 87/100, Loss: 0.6931
# Epoch 88/100, Loss: 0.6931
# Epoch 89/100, Loss: 0.6931
# Epoch 90/100, Loss: 0.6931
# Epoch 91/100, Loss: 0.6931
# Epoch 92/100, Loss: 0.6931
# Epoch 93/100, Loss: 0.6931
# Epoch 94/100, Loss: 0.6931
# Epoch 95/100, Loss: 0.6931
# Epoch 96/100, Loss: 0.6931
# Epoch 97/100, Loss: 0.6931
# Epoch 98/100, Loss: 0.6931
# Epoch 99/100, Loss: 0.6931
# Epoch 100/100, Loss: 0.6931
# Test Precision: 0.0000
# Test Recall: 0.0000
# Test F1 Score: 0.0000
# Test ROC-AUC Score: 0.4995
# Test AUPRC Score: 0.0896
# Confusion Matrix:
# [[664   0]
#  [ 45   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.94      1.00      0.97       664
#          1.0       0.00      0.00      0.00        45
#
#     accuracy                           0.94       709
#    macro avg       0.47      0.50      0.48       709
# weighted avg       0.88      0.94      0.91       709
#
# Fold 9
# Training with learning rate: 0.001, dropout: 0.2, channels: 64, kernel size: 3
# c:\Users\Grego\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Grego\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Grego\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Grego\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Found new best hyperparameters: (0.001, 0.2, 64, 3)
# Training with learning rate: 0.001, dropout: 0.2, channels: 64, kernel size: 5
# Training with learning rate: 0.001, dropout: 0.2, channels: 128, kernel size: 3
# Found new best hyperparameters: (0.001, 0.2, 128, 3)
# Training with learning rate: 0.001, dropout: 0.2, channels: 128, kernel size: 5
# Training with learning rate: 0.001, dropout: 0.5, channels: 64, kernel size: 3
# Training with learning rate: 0.001, dropout: 0.5, channels: 64, kernel size: 5
# Training with learning rate: 0.001, dropout: 0.5, channels: 128, kernel size: 3
# Training with learning rate: 0.001, dropout: 0.5, channels: 128, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.2, channels: 64, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.2, channels: 64, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.2, channels: 128, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.2, channels: 128, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.5, channels: 64, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.5, channels: 64, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.5, channels: 128, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.5, channels: 128, kernel size: 5
# Best Hyperparameters for Fold 9: (0.001, 0.2, 128, 3)
# Training on full training set with best hyperparameters: (0.001, 0.2, 128, 3)
# Epoch 1/100, Loss: 0.7160
# Epoch 2/100, Loss: 0.6936
# Epoch 3/100, Loss: 0.6933
# Epoch 4/100, Loss: 0.6932
# Epoch 5/100, Loss: 0.6932
# Epoch 6/100, Loss: 0.6932
# Epoch 7/100, Loss: 0.6932
# Epoch 8/100, Loss: 0.6932
# Epoch 9/100, Loss: 0.6932
# Epoch 10/100, Loss: 0.6932
# Epoch 11/100, Loss: 0.6932
# Epoch 12/100, Loss: 0.6932
# Epoch 13/100, Loss: 0.6932
# Epoch 14/100, Loss: 0.6932
# Epoch 15/100, Loss: 0.6932
# Epoch 16/100, Loss: 0.6932
# Epoch 17/100, Loss: 0.6932
# Epoch 18/100, Loss: 0.6932
# Epoch 19/100, Loss: 0.6932
# Epoch 20/100, Loss: 0.6931
# Epoch 21/100, Loss: 0.6931
# Epoch 22/100, Loss: 0.6931
# Epoch 23/100, Loss: 0.6931
# Epoch 24/100, Loss: 0.6931
# Epoch 25/100, Loss: 0.6931
# Epoch 26/100, Loss: 0.6931
# Epoch 27/100, Loss: 0.6931
# Epoch 28/100, Loss: 0.6931
# Epoch 29/100, Loss: 0.6931
# Epoch 30/100, Loss: 0.6931
# Epoch 31/100, Loss: 0.6931
# Epoch 32/100, Loss: 0.6931
# Epoch 33/100, Loss: 0.6931
# Epoch 34/100, Loss: 0.6931
# Epoch 35/100, Loss: 0.6931
# Epoch 36/100, Loss: 0.6931
# Epoch 37/100, Loss: 0.6931
# Epoch 38/100, Loss: 0.6931
# Epoch 39/100, Loss: 0.6931
# Epoch 40/100, Loss: 0.6931
# Epoch 41/100, Loss: 0.6931
# Epoch 42/100, Loss: 0.6931
# Epoch 43/100, Loss: 0.6931
# Epoch 44/100, Loss: 0.6931
# Epoch 45/100, Loss: 0.6931
# Epoch 46/100, Loss: 0.6931
# Epoch 47/100, Loss: 0.6931
# Epoch 48/100, Loss: 0.6931
# Epoch 49/100, Loss: 0.6931
# Epoch 50/100, Loss: 0.6931
# Epoch 51/100, Loss: 0.6931
# Epoch 52/100, Loss: 0.6931
# Epoch 53/100, Loss: 0.6931
# Epoch 54/100, Loss: 0.6931
# Epoch 55/100, Loss: 0.6931
# Epoch 56/100, Loss: 0.6931
# Epoch 57/100, Loss: 0.6931
# Epoch 58/100, Loss: 0.6931
# Epoch 59/100, Loss: 0.6931
# Epoch 60/100, Loss: 0.6931
# Epoch 61/100, Loss: 0.6931
# Epoch 62/100, Loss: 0.6931
# Epoch 63/100, Loss: 0.6931
# Epoch 64/100, Loss: 0.6931
# Epoch 65/100, Loss: 0.6931
# Epoch 66/100, Loss: 0.6931
# Epoch 67/100, Loss: 0.6931
# Epoch 68/100, Loss: 0.6931
# Epoch 69/100, Loss: 0.6931
# Epoch 70/100, Loss: 0.6931
# Epoch 71/100, Loss: 0.6931
# Epoch 72/100, Loss: 0.6931
# Epoch 73/100, Loss: 0.6931
# Epoch 74/100, Loss: 0.6931
# Epoch 75/100, Loss: 0.6931
# Epoch 76/100, Loss: 0.6931
# Epoch 77/100, Loss: 0.6931
# Epoch 78/100, Loss: 0.6931
# Epoch 79/100, Loss: 0.6931
# Epoch 80/100, Loss: 0.6931
# Epoch 81/100, Loss: 0.6931
# Epoch 82/100, Loss: 0.6931
# Epoch 83/100, Loss: 0.6931
# Epoch 84/100, Loss: 0.6931
# Epoch 85/100, Loss: 0.6931
# Epoch 86/100, Loss: 0.6931
# Epoch 87/100, Loss: 0.6931
# Epoch 88/100, Loss: 0.6931
# Epoch 89/100, Loss: 0.6931
# Epoch 90/100, Loss: 0.6931
# Epoch 91/100, Loss: 0.6931
# Epoch 92/100, Loss: 0.6931
# Epoch 93/100, Loss: 0.6930
# Epoch 94/100, Loss: 0.6930
# Epoch 95/100, Loss: 0.6930
# Epoch 96/100, Loss: 0.6930
# Epoch 97/100, Loss: 0.6930
# Epoch 98/100, Loss: 0.6930
# Epoch 99/100, Loss: 0.6930
# Epoch 100/100, Loss: 0.6930
# Test Precision: 0.0000
# Test Recall: 0.0000
# Test F1 Score: 0.0000
# Test ROC-AUC Score: 0.4710
# Test AUPRC Score: 0.0533
# Confusion Matrix:
# [[669   0]
#  [ 40   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.94      1.00      0.97       669
#          1.0       0.00      0.00      0.00        40
#
#     accuracy                           0.94       709
#    macro avg       0.47      0.50      0.49       709
# weighted avg       0.89      0.94      0.92       709
#
# Fold 10
# Training with learning rate: 0.001, dropout: 0.2, channels: 64, kernel size: 3
# c:\Users\Grego\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Grego\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Grego\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Grego\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Found new best hyperparameters: (0.001, 0.2, 64, 3)
# Training with learning rate: 0.001, dropout: 0.2, channels: 64, kernel size: 5
# Found new best hyperparameters: (0.001, 0.2, 64, 5)
# Training with learning rate: 0.001, dropout: 0.2, channels: 128, kernel size: 3
# Found new best hyperparameters: (0.001, 0.2, 128, 3)
# Training with learning rate: 0.001, dropout: 0.2, channels: 128, kernel size: 5
# Training with learning rate: 0.001, dropout: 0.5, channels: 64, kernel size: 3
# Training with learning rate: 0.001, dropout: 0.5, channels: 64, kernel size: 5
# Training with learning rate: 0.001, dropout: 0.5, channels: 128, kernel size: 3
# Training with learning rate: 0.001, dropout: 0.5, channels: 128, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.2, channels: 64, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.2, channels: 64, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.2, channels: 128, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.2, channels: 128, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.5, channels: 64, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.5, channels: 64, kernel size: 5
# Training with learning rate: 0.01, dropout: 0.5, channels: 128, kernel size: 3
# Training with learning rate: 0.01, dropout: 0.5, channels: 128, kernel size: 5
# Best Hyperparameters for Fold 10: (0.001, 0.2, 128, 3)
# Training on full training set with best hyperparameters: (0.001, 0.2, 128, 3)
# Epoch 1/100, Loss: 0.7143
# Epoch 2/100, Loss: 0.6936
# Epoch 3/100, Loss: 0.6933
# Epoch 4/100, Loss: 0.6932
# Epoch 5/100, Loss: 0.6932
# Epoch 6/100, Loss: 0.6932
# Epoch 7/100, Loss: 0.6932
# Epoch 8/100, Loss: 0.6932
# Epoch 9/100, Loss: 0.6932
# Epoch 10/100, Loss: 0.6932
# Epoch 11/100, Loss: 0.6932
# Epoch 12/100, Loss: 0.6932
# Epoch 13/100, Loss: 0.6932
# Epoch 14/100, Loss: 0.6932
# Epoch 15/100, Loss: 0.6932
# Epoch 16/100, Loss: 0.6932
# Epoch 17/100, Loss: 0.6932
# Epoch 18/100, Loss: 0.6932
# Epoch 19/100, Loss: 0.6931
# Epoch 20/100, Loss: 0.6931
# Epoch 21/100, Loss: 0.6931
# Epoch 22/100, Loss: 0.6931
# Epoch 23/100, Loss: 0.6931
# Epoch 24/100, Loss: 0.6931
# Epoch 25/100, Loss: 0.6931
# Epoch 26/100, Loss: 0.6931
# Epoch 27/100, Loss: 0.6931
# Epoch 28/100, Loss: 0.6931
# Epoch 29/100, Loss: 0.6931
# Epoch 30/100, Loss: 0.6931
# Epoch 31/100, Loss: 0.6931
# Epoch 32/100, Loss: 0.6931
# Epoch 33/100, Loss: 0.6931
# Epoch 34/100, Loss: 0.6931
# Epoch 35/100, Loss: 0.6931
# Epoch 36/100, Loss: 0.6931
# Epoch 37/100, Loss: 0.6931
# Epoch 38/100, Loss: 0.6931
# Epoch 39/100, Loss: 0.6931
# Epoch 40/100, Loss: 0.6931
# Epoch 41/100, Loss: 0.6931
# Epoch 42/100, Loss: 0.6931
# Epoch 43/100, Loss: 0.6931
# Epoch 44/100, Loss: 0.6931
# Epoch 45/100, Loss: 0.6931
# Epoch 46/100, Loss: 0.6931
# Epoch 47/100, Loss: 0.6931
# Epoch 48/100, Loss: 0.6931
# Epoch 49/100, Loss: 0.6931
# Epoch 50/100, Loss: 0.6931
# Epoch 51/100, Loss: 0.6931
# Epoch 52/100, Loss: 0.6931
# Epoch 53/100, Loss: 0.6931
# Epoch 54/100, Loss: 0.6931
# Epoch 55/100, Loss: 0.6931
# Epoch 56/100, Loss: 0.6931
# Epoch 57/100, Loss: 0.6931
# Epoch 58/100, Loss: 0.6931
# Epoch 59/100, Loss: 0.6931
# Epoch 60/100, Loss: 0.6930
# Epoch 61/100, Loss: 0.6930
# Epoch 62/100, Loss: 0.6930
# Epoch 63/100, Loss: 0.6930
# Epoch 64/100, Loss: 0.6930
# Epoch 65/100, Loss: 0.6930
# Epoch 66/100, Loss: 0.6930
# Epoch 67/100, Loss: 0.6930
# Epoch 68/100, Loss: 0.6930
# Epoch 69/100, Loss: 0.6930
# Epoch 70/100, Loss: 0.6930
# Epoch 71/100, Loss: 0.6930
# Epoch 72/100, Loss: 0.6930
# Epoch 73/100, Loss: 0.6930
# Epoch 74/100, Loss: 0.6930
# Epoch 75/100, Loss: 0.6930
# Epoch 76/100, Loss: 0.6930
# Epoch 77/100, Loss: 0.6930
# Epoch 78/100, Loss: 0.6930
# Epoch 79/100, Loss: 0.6930
# Epoch 80/100, Loss: 0.6930
# Epoch 81/100, Loss: 0.6930
# Epoch 82/100, Loss: 0.6930
# Epoch 83/100, Loss: 0.6930
# Epoch 84/100, Loss: 0.6930
# Epoch 85/100, Loss: 0.6930
# Epoch 86/100, Loss: 0.6930
# Epoch 87/100, Loss: 0.6930
# Epoch 88/100, Loss: 0.6930
# Epoch 89/100, Loss: 0.6930
# Epoch 90/100, Loss: 0.6930
# Epoch 91/100, Loss: 0.6930
# Epoch 92/100, Loss: 0.6930
# Epoch 93/100, Loss: 0.6930
# Epoch 94/100, Loss: 0.6930
# Epoch 95/100, Loss: 0.6929
# Epoch 96/100, Loss: 0.6929
# Epoch 97/100, Loss: 0.6929
# Epoch 98/100, Loss: 0.6929
# Epoch 99/100, Loss: 0.6929
# Epoch 100/100, Loss: 0.6929
# Test Precision: 0.0000
# Test Recall: 0.0000
# Test F1 Score: 0.0000
# Test ROC-AUC Score: 0.4989
# Test AUPRC Score: 0.0559
# Confusion Matrix:
# [[667   0]
#  [ 42   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.94      1.00      0.97       667
#          1.0       0.00      0.00      0.00        42
#
#     accuracy                           0.94       709
#    macro avg       0.47      0.50      0.48       709
# weighted avg       0.89      0.94      0.91       709
# c:\Users\Grego\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Grego\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Grego\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Grego\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
list_of_dicts = []
def format_confusion_matrix(conf_matrix):
    return f"[[{conf_matrix[0][0]}, {conf_matrix[0][1]}]\n [{conf_matrix[1][0]}, {conf_matrix[1][1]}]]"

print('\n')
for fold, i in enumerate(best_results_per_fold):
    cleaned_conf_matrix = i[2]
    # i[1] round to 4 decimal places
    cleaned_hyperparameters = i[0]
    converted_auc = round(i[1], 4)
    print(converted_auc)
    #print(format_confusion_matrix(cleaned_conf_matrix))
    list_of_dicts.append({'Hyperparameters': cleaned_conf_matrix})

# Print the DataFrame without the index
print(pd.DataFrame(list_of_dicts).to_string(index=False))

print(f"Dataset name is: {DATASET_PATH}")
# Out:
# 0.606
# 0.5602
# 0.6414
# 0.6494
# 0.5736
# 0.5786
# 0.5939
# 0.543
# 0.5676
# 0.5787
#     Hyperparameters
# [[595, 0], [44, 0]]
# [[586, 0], [53, 0]]
# [[596, 1], [42, 0]]
# [[604, 0], [35, 0]]
# [[610, 0], [28, 1]]
# [[594, 2], [43, 0]]
# [[604, 1], [33, 1]]
# [[601, 0], [38, 0]]
# [[600, 0], [39, 0]]
# [[597, 0], [42, 0]]
# Dataset name is: ../../data/stroke_dataset.csv
